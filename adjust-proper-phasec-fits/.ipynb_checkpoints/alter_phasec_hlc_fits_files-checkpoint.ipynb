# %% [markdown]
# # Import the necessary packages and define the path to the phaseb_data directory as well as the new directory you would like to save the altered files to.

# %%
from astropy.io import fits
import astropy.units as u
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'image.origin': 'lower'})
import os
from pathlib import Path

import roman_phasec_proper as phasec
hlcdir_old = Path(phasec.data_dir+'/hlc_20190210b')

import cgi_phasec_poppy
hlcdir = cgi_phasec_poppy.data_dir/'hlc' # path to new directory

from cgi_phasec_poppy import misc

pupil_diam = 2.363114*u.m
pupil_diam_pix = 309*u.pixel

# %% [markdown]
# # Add pupil scales to the pupil files.

# %%
pupil_fnames = ['pupil.fits', 'pupil_rotated.fits']

for fname in pupil_fnames:
    hlc575pup = fits.open(hlcdir_old/fname)
    hlc575pup_data = hlc575pup[0].data
    hlc575pup.close()
    
    print(hlc575pup_data.shape)
#     arr = np.zeros(shape=(312,312))
#     arr[1:,1:] = hlc575pup_data
# #     arr[:-1,:-1] = hlc575pup_data
#     hlc575pup_data = arr
    
    hdr = fits.Header()
    hdr['PUPLSCAL'] = pupil_diam.value/pupil_diam_pix.value
    hdr['PIXELSCL'] = pupil_diam.value/pupil_diam_pix.value
    hlc575pup_new = fits.PrimaryHDU(data=hlc575pup_data, header=hdr)
    hlc575pup_new.writeto(hlcdir/fname, overwrite=True)
    print(hlcdir/fname)
    print(pupil_diam/pupil_diam_pix, hlc575pup_data.shape)
    misc.myimshow(hlc575pup_data, pxscl=pupil_diam/pupil_diam_pix)
# Out:
# (311, 311)
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/pupil.fits
# 0.007647618122977346 m / pix (311, 311)
# (311, 311)
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/pupil_rotated.fits
# 0.007647618122977346 m / pix (311, 311)

# %% [markdown]
# # Adjust the mask file for DM2.

# %%
fname = 'dm2mask.fits'

dm2mask = fits.open(hlcdir_old/fname)
dm2_mask = dm2mask[0].data
dm2mask.close()

misc.myimshow(dm2_mask)

hdr = fits.Header()
# hdr['PIXELSCL'] = 0.000149838439214385
hdr['PIXELSCL'] = 0.00014935510078279346
dm2mask_new = fits.PrimaryHDU(data=dm2_mask, header=hdr)
dm2mask_new.writeto(hlcdir/fname, overwrite=True)
print(hlcdir/fname)
# Out:
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/dm2mask.fits

# %% [markdown]
# # Add pixel scales to the FPM files.

# %%
from scipy.ndimage import rotate

def rotate_180(arr):
    M = arr.shape[0]
    N = arr.shape[1]
    rot_arr = np.zeros(shape=(N,M))
    for i in range(M):
        for j in range(N):
            rot_arr[i, N-1-j] = arr[M-1-i, j]
    return rot_arr
            
f = open( str(hlcdir_old/'fpm_files.txt') )
fpm_nlam = int(f.readline())
fpm_lams = np.zeros((fpm_nlam),dtype=float)
for j in range(0,fpm_nlam): 
    fpm_lams[j] = float(f.readline())*1e-6
fpm_root_fnames = [j.strip() for j in f.readlines()] 
f.close()

print(fpm_lams)
print(fpm_root_fnames)

for fpm_rootname in fpm_root_fnames:
    fpm_r = fits.getdata(str(hlcdir_old/fpm_rootname)+'real.fits')
    fpm_i = fits.getdata(str(hlcdir_old/fpm_rootname)+'imag.fits')
    fpm_lambda_m = fits.getheader(str(hlcdir_old/fpm_rootname)+'real.fits')['FPMLAM0M']
    fpm_pxscl_lamD = fits.getheader(str(hlcdir_old/fpm_rootname)+'real.fits')['FPMDX']
    fpm_pxscl_as = (fpm_pxscl_lamD*(fpm_lambda_m/pupil_diam.value)*u.radian/u.pix).to(u.arcsec/u.pix)
    print(fpm_lambda_m, fpm_pxscl_lamD, fpm_pxscl_as)
    
#     fpm_r = rotate(fpm_r, 180)
#     fpm_i = rotate(fpm_i, 180)
    fpm_r = rotate_180(fpm_r)
    fpm_i = rotate_180(fpm_i)

#     arr = np.ones(shape=(268,268))
#     arr[:-1,:-1] = fpm_r
#     fpm_r = arr
#     arr = np.zeros(shape=(268,268))
#     arr[:-1,:-1] = fpm_i
#     fpm_i = arr
    
    arr = np.ones(shape=(268,268))
    arr[1:,1:] = fpm_r
    fpm_r = arr
    arr = np.zeros(shape=(268,268))
    arr[1:,1:] = fpm_i
    fpm_i = arr
    
#     arr = np.zeros(shape=(269,269))
#     arr[1:-1,1:-1] = fpm_r
#     fpm_r = arr
#     arr = np.zeros(shape=(269,269))
#     arr[1:-1,1:-1] = fpm_i
#     fpm_i = arr
    
    print(str(hlcdir/fpm_rootname)+'real.fits', fpm_r.shape)
    hdr = fits.Header()
    hdr['PIXELSCL'] = fpm_pxscl_as.value
    hdr['WAVELENC'] = 0.575e-6
    hdr['PUPLDIAM'] = pupil_diam.value
    hdr['PIXSCLLD'] = fpm_pxscl_lamD
    hlc575fpm_r_new = fits.PrimaryHDU(data=fpm_r, header=hdr)
    hlc575fpm_r_new.writeto(str(hlcdir/fpm_rootname)+'real.fits', overwrite=True)
    
    hdr = fits.Header(); 
    hdr['PIXELSCL'] = fpm_pxscl_as.value
    hdr['WAVELENC'] = 0.575e-6
    hdr['PUPLDIAM'] = pupil_diam.value
    hdr['PIXSCLLD'] = fpm_pxscl_lamD
    hlc575fpm_i_new = fits.PrimaryHDU(data=fpm_i, header=hdr)
    hlc575fpm_i_new.writeto(str(hlcdir/fpm_rootname)+'imag.fits', overwrite=True)
    
    if '0.57500000um' in fpm_rootname or '0.54625000um' in fpm_rootname or '0.60375000um' in fpm_rootname:
        misc.myimshow2(fpm_r, fpm_i, pxscl=fpm_pxscl_as)
# Out:
# [5.4625000e-07 5.4627000e-07 5.5104167e-07 5.5113500e-07 5.5583333e-07
#  5.5600000e-07 5.6062500e-07 5.6086500e-07 5.6541667e-07 5.6551250e-07
#  5.6573000e-07 5.7020833e-07 5.7025625e-07 5.7500000e-07 5.7974375e-07
#  5.7979167e-07 5.8448750e-07 5.8449600e-07 5.8458333e-07 5.8924800e-07
#  5.8937500e-07 5.9400000e-07 5.9416667e-07 5.9875200e-07 5.9895833e-07
#  6.0350400e-07 6.0375000e-07]
# ['hlc_fpm_trans_0.54625000um_', 'hlc_fpm_trans_0.54627000um_', 'hlc_fpm_trans_0.55104167um_', 'hlc_fpm_trans_0.55113500um_', 'hlc_fpm_trans_0.55583333um_', 'hlc_fpm_trans_0.55600000um_', 'hlc_fpm_trans_0.56062500um_', 'hlc_fpm_trans_0.56086500um_', 'hlc_fpm_trans_0.56541667um_', 'hlc_fpm_trans_0.56551250um_', 'hlc_fpm_trans_0.56573000um_', 'hlc_fpm_trans_0.57020833um_', 'hlc_fpm_trans_0.57025625um_', 'hlc_fpm_trans_0.57500000um_', 'hlc_fpm_trans_0.57974375um_', 'hlc_fpm_trans_0.57979167um_', 'hlc_fpm_trans_0.58448750um_', 'hlc_fpm_trans_0.58449600um_', 'hlc_fpm_trans_0.58458333um_', 'hlc_fpm_trans_0.58924800um_', 'hlc_fpm_trans_0.58937500um_', 'hlc_fpm_trans_0.59400000um_', 'hlc_fpm_trans_0.59416667um_', 'hlc_fpm_trans_0.59875200um_', 'hlc_fpm_trans_0.59895833um_', 'hlc_fpm_trans_0.60350400um_', 'hlc_fpm_trans_0.60375000um_']
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.54625000um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.54627000um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.55104167um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.55113500um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.55583333um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.55600000um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.56062500um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.56086500um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.56541667um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.56551250um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.56573000um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.57020833um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.57025625um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.57500000um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.57974375um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.57979167um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.58448750um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.58449600um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.58458333um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.58924800um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.58937500um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.59400000um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.59416667um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.59875200um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.59895833um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.60350400um_real.fits (268, 268)
# 5.75e-07 0.0267002377265 0.0013400574973571157 arcsec / pix
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.60375000um_real.fits (268, 268)

# %% [markdown]
# # Add pupil scales to the lyot stop files.

# %%
ls_fnames = ['lyot.fits', 'lyot_rotated.fits']
ls_sampling = 5.50105901118828e-05*u.m

for i,fname in enumerate(ls_fnames):
    hlc575ls = fits.open(hlcdir_old/fname)
    ls_data = hlc575ls[0].data
    hlc575ls.close()
    
#     arr = np.zeros(shape=(312,312))
#     arr[1:,1:] = ls_data
# #     arr[:-1,:-1] = ls_data
#     ls_data = arr
    
    hdr = fits.Header()
    hdr['PIXELSCL'] = ls_sampling.value
    ls_new = fits.PrimaryHDU(data=ls_data, header=hdr)
    ls_new.writeto(hlcdir/fname, overwrite=True)
    print(str(hlcdir/fname))
    print(ls_data.shape, ls_sampling)
    misc.myimshow(ls_data, pxscl=ls_sampling/u.pix)
# Out:
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/lyot.fits
# (311, 311) 5.50105901118828e-05 m
# /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/lyot_rotated.fits
# (311, 311) 5.50105901118828e-05 m
