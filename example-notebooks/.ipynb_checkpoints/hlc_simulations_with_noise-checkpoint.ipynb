# %%
import numpy as np
import cupy as cp
import ray
import astropy.units as u
from astropy.io import fits
from IPython.display import clear_output
import time
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# import warnings
# warnings.filterwarnings("ignore")

import poppy

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
poppy_log.disabled = True

import cgi_phasec_poppy as cgi
import misc_funs as misc

from importlib import reload
reload(cgi)

wavelength_c = 575e-9*u.m

nlam = 3
bandwidth = 0.10
minlam = wavelength_c * (1 - bandwidth/2)
maxlam = wavelength_c * (1 + bandwidth/2)
wavelengths = np.linspace( minlam, maxlam, nlam )

pixelscale_lamD = 0.2

iwa = 2.8
owa = 9.7

data_dir = cgi.data_dir

dm1_flat = 2*fits.getdata(data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')

# %%
from astropy.constants import h, c, k_B

pupil_diam = 2.4*u.m
d = (14.06*u.parsec).to(u.m)
SA = (((pupil_diam/d)*u.radian)**2).to(u.sr)

T = 5887*u.K

lambdas = np.linspace(400, 700, 10000)*u.nm

spec = 2*h*c**2/(lambdas**5)/(np.exp(h*c/(k_B*T*lambdas)) - 1)/u.sr

spec = spec.to(u.J/u.s/u.sr/u.m**2/u.nm) * SA

plt.plot(lambdas, spec)

# %%
from scipy.integrate import simpson

fluxes = []

del_waves = wavelengths[1]-wavelengths[0]

for i in range(nlam):
    wave = wavelengths[i].to(u.nm)
    min_wave = wave-del_waves/2
    max_wave = wave+del_waves/2
    inds = np.where((lambdas>min_wave)&(lambdas<max_wave))
    
    wave_range = lambdas[inds].value
    spec_range = spec[inds].value
#     print(wave_range[0], wave_range[-1])
    
    fluxes.append(simpson(spec_range, wave_range)*u.J/u.s/u.m**2) # integrate over the wave band
    
    E = h*c/wave.to(u.m) / u.photon
    
    fluxes[i] /= E # convert to photons/s/m**2
    
print(fluxes)
# Out:
# [<Quantity 6.82063757e-11 ph / (m2 s)>, <Quantity 6.96922263e-11 ph / (m2 s)>, <Quantity 7.05067913e-11 ph / (m2 s)>]

# %%
reload(cgi)
hlc = cgi.CGI(cgi_mode='hlc', 
              psf_pixelscale_lamD=pixelscale_lamD, 
              npsf=128, 
              use_pupil_defocus=True, 
              use_opds=True,
              use_noise=True,
              texp=1e20*u.s,
              star_flux=fluxes[1])

hlc.set_dm1(dm1_flat)
hlc.set_dm2(dm2_flat)

im = hlc.snap()

misc.imshow1(im, lognorm=True)
# Out:
# c:\users\kian\documents\src\poppy\poppy\geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
#   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# c:\users\kian\documents\src\poppy\poppy\geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
#   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')

# %%
kwargs = {'cgi_mode':'hlc',
          'psf_pixelscale_lamD':pixelscale_lamD,
          'npsf':128,
          'use_pupil_defocus':True, 
          'use_opds':True,
          'use_noise':True,
          'texp':1e18*u.s,}
actors = []
for i in range(nlam):
    actors.append(ray.remote(cgi.CGI).options(num_gpus=1/3).remote(wavelength=wavelengths[i], 
                                                                   star_flux=fluxes[i],
                                                                   **kwargs))

# %%
pending_ims = []
for i in range(len(actors)):
    actors[i].set_dm1.remote(dm1_flat) # set the DM state for each actor in this loop
    actors[i].set_dm2.remote(dm2_flat)
    future_ims = actors[i].snap.remote()
    pending_ims.append(future_ims)
ims = ray.get(pending_ims)

im = np.sum(ims, axis=0)/nlam

misc.imshow3(ims[0], ims[1], ims[2], 
             'PSF: $\lambda={:.2e}$'.format(wavelengths[0]), 
             'PSF: $\lambda={:.2e}$'.format(wavelengths[1]),
             'PSF: $\lambda={:.2e}$'.format(wavelengths[2]),
             pxscl=hlc.psf_pixelscale_lamD, xlabel='$\lambda/D$',
             lognorm=True)

misc.imshow1(im, lognorm=True, pxscl=hlc.psf_pixelscale_lamD)
# Out:
#  pid=8968) After resampling, optic phasor shape (324, 324) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (324, 324) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (405, 405) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (405, 405) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (324, 324) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (405, 405) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (337, 337) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (339, 339) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (399, 399) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (337, 337) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (339, 339) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (399, 399) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (459, 459) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (337, 337) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (339, 339) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (399, 399) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (459, 459) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (459, 459) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (508, 508) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (508, 508) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (466, 466) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (508, 508) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (466, 466) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) c:\users\kian\documents\src\poppy\poppy\geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
#  pid=4888)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
#  pid=4888) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) c:\users\kian\documents\src\poppy\poppy\geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
#  pid=4888)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
#  pid=8968) c:\users\kian\documents\src\poppy\poppy\geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
#  pid=8968)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
#  pid=8968) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) c:\users\kian\documents\src\poppy\poppy\geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
#  pid=8968)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
#  pid=8968) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (466, 466) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) c:\users\kian\documents\src\poppy\poppy\geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
#  pid=20800)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
#  pid=20800) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) c:\users\kian\documents\src\poppy\poppy\geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
#  pid=20800)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
#  pid=20800) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (581, 581) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (581, 581) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (581, 581) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=20800) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=8968) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
#  pid=4888) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
