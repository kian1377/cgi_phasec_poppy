# %%
import numpy as np
import cupy as cp
import ray
import astropy.units as u
from astropy.io import fits
from IPython.display import clear_output
import time
from pathlib import Path
from matplotlib.patches import Circle
from importlib import reload

import warnings
warnings.filterwarnings("ignore")

import poppy

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
poppy_log.disabled = True

import cgi_phasec_poppy as cgi
reload(cgi)

import misc_funs as misc

iwa = 2.8
owa = 9.7

cgi.data_dir = Path('/groups/douglase/kians-data-files/roman-cgi-phasec-data')

dm1_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')

# %% [markdown]
# # Test monochromatic PSFs.

# %%
reload(cgi)
cgi.data_dir = Path('/groups/douglase/kians-data-files/roman-cgi-phasec-data')
mode = cgi.CGI(cgi_mode='hlc', 
               use_pupil_defocus=True, 
               use_opds=False,
               polaxis=0)

wf = mode.calc_psf(quiet=False)
psf = np.abs(wf)**2

patches = [Circle((0, 0), iwa, color='c', fill=False), Circle((0, 0), owa, color='c', fill=False)]
misc.imshow1(psf, lognorm=True, pxscl=mode.psf_pixelscale_lamD, patches=patches)

if poppy.accel_math._USE_CUPY:
    misc.save_fits(cgi.data_dir/'hlc_psf_gpu.fits', psf, header={'PIXELSCL':mode.psf_pixelscale_lamD})
else:
    misc.save_fits(cgi.data_dir/'hlc_psf_cpu.fits', psf, header={'PIXELSCL':mode.psf_pixelscale_lamD})
# Out:
# Propagating wavelength 575.000 nm.
# PSF calculated in 0.818s
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc_psf_gpu.fits

# %%
# %%timeit
wf = mode.calc_psf(quiet=True)
# Out:
# 269 ms ± 1.05 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
mode = cgi.CGI(cgi_mode='hlc', 
               use_pupil_defocus=True, 
               use_opds=True,
               polaxis=10)

mode.set_dm1(dm1_flat)
mode.set_dm2(dm2_flat)

wf = mode.calc_psf(quiet=False)
psf = np.abs(wf)**2

patches = [Circle((0, 0), iwa, color='c', fill=False), Circle((0, 0), owa, color='c', fill=False)]
misc.imshow1(psf, lognorm=True, pxscl=mode.psf_pixelscale_lamD, patches=patches)

if poppy.accel_math._USE_CUPY:
    misc.save_fits(cgi.data_dir/'hlc_opds_psf_gpu.fits', psf, header={'PIXELSCL':mode.psf_pixelscale_lamD})
else:
    misc.save_fits(cgi.data_dir/'hlc_opds_psf_cpu.fits', psf, header={'PIXELSCL':mode.psf_pixelscale_lamD})
# Out:
# Propagating wavelength 575.000 nm.
# PSF calculated in 0.320s
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc_opds_psf_gpu.fits

# %%
# %%timeit
wf = mode.calc_psf(quiet=True)
# Out:
# 311 ms ± 810 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Test broadband PSFs with GPU parallelization.

# %% [markdown]
# ### Create the actors to calculate each individual PSF/image with ray.remote() actors.
#
# num_gpus can be set to whatever fractional GPU the user desires, but this can cause issues when using many actors at once. For example, if your GPU doesn't have the computational capabilities or memory to assign each actor to 1/10 of the GPU, than this will make the code run slower, not faster.

# %%
reload(cgi)
rayCGI = ray.remote(cgi.CGI) # make a ray actor class from the original CGI class  

wavelength_c = 575e-9*u.m

nlam = 3
bandwidth = 0.10
minlam = wavelength_c * (1 - bandwidth/2)
maxlam = wavelength_c * (1 + bandwidth/2)
wavelengths = np.linspace( minlam, maxlam, nlam )

kwargs = {'cgi_mode':'hlc',
          'use_pupil_defocus':True,
          'use_opds':True}
actors = []
for i in range(nlam):
    actors.append(rayCGI.remote(wavelength=wavelengths[i], **kwargs))

# %% [markdown]
# ### Calculate each image by calling the remote function of each actor.

# %%
pending_ims = []
for i in range(len(actors)):
    actors[i].set_dm1.remote(dm1_flat) # set the DM state for each actor in this loop
    actors[i].set_dm2.remote(dm2_flat)
    future_ims = actors[i].snap.remote()
    pending_ims.append(future_ims)
ims = ray.get(pending_ims)
clear_output()

for i in range(len(actors)):
    misc.imshow1(ims[i], 
                 'PSF: $\lambda={:.2f}$'.format(ray.get(actors[i].getattr.remote('wavelength_c')).to(u.nm)), 
                 pxscl=mode.psf_pixelscale_lamD, xlabel='$\lambda/D$',
                 lognorm=True)
    
psf_broad = np.sum(ims, axis=0)/nlam

patches = [Circle((0, 0), iwa, color='c', fill=False), Circle((0, 0), owa, color='c', fill=False)]
misc.imshow1(psf_broad, 'Broadband PSF', lognorm=True, pxscl=mode.psf_pixelscale_lamD, patches=patches)

if poppy.accel_math._USE_CUPY:
    misc.save_fits(cgi.data_dir/'hlc_psf_broad_gpu.fits', psf_broad, header={'PIXELSCL':mode.psf_pixelscale_lamD})
else:
    misc.save_fits(cgi.data_dir/'hlc_psf_broad_cpu.fits', psf_broad, header={'PIXELSCL':mode.psf_pixelscale_lamD})
# Out:
# (CGI pid=146120) After resampling, optic phasor shape (324, 324) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (324, 324) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (324, 324) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (405, 405) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (405, 405) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (405, 405) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (337, 337) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (337, 337) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (337, 337) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (339, 339) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (339, 339) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (339, 339) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (399, 399) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (399, 399) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (399, 399) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (459, 459) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (459, 459) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (459, 459) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (508, 508) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (508, 508) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (508, 508) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (466, 466) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (466, 466) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (466, 466) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) /home/u21/kianmilani/src/poppy/poppy/geometry.py:207: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=146120)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=146121) /home/u21/kianmilani/src/poppy/poppy/geometry.py:207: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=146121)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=146119) /home/u21/kianmilani/src/poppy/poppy/geometry.py:207: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=146119)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=146120) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) /home/u21/kianmilani/src/poppy/poppy/geometry.py:207: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=146120)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=146121) /home/u21/kianmilani/src/poppy/poppy/geometry.py:207: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=146121)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=146119) /home/u21/kianmilani/src/poppy/poppy/geometry.py:207: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=146119)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=146120) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (581, 581) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (581, 581) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (581, 581) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (635, 635) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (637, 637) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146120) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146121) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# (CGI pid=146119) After resampling, optic phasor shape (636, 636) is smaller than input wavefront (1024, 1024); will zero-pad the rescaled array.
# ---------------------------------------------------------------------------
# RayTaskError(AttributeError)              Traceback (most recent call last)
# Input In [10], in <cell line: 7>()
#       5     future_ims = actors[i].snap.remote()
#       6     pending_ims.append(future_ims)
# ----> 7 ims = ray.get(pending_ims)
#       8 clear_output()
#      10 for i in range(len(actors)):
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/ray/worker.py:1809, in get(object_refs, timeout)
#    1807     worker.core_worker.dump_object_store_memory_usage()
#    1808 if isinstance(value, RayTaskError):
# -> 1809     raise value.as_instanceof_cause()
#    1810 else:
#    1811     raise value
#
# RayTaskError(AttributeError): ray::CGI.snap() (pid=146120, ip=10.141.18.33, repr=<cgi_phasec_poppy.cgi.CGI object at 0x7f9d91ead400>)
#   File "/home/u21/kianmilani/src/cgi-phasec-poppy/cgi_phasec_poppy/cgi.py", line 439, in snap
#     return wfs[-1].intensity.get()
# AttributeError: 'numpy.ndarray' object has no attribute 'get'
# 2023-03-27 12:06:22,787	ERROR worker.py:92 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::CGI.snap() (pid=146121, ip=10.141.18.33, repr=<cgi_phasec_poppy.cgi.CGI object at 0x7f8e25bdf070>)
#   File "/home/u21/kianmilani/src/cgi-phasec-poppy/cgi_phasec_poppy/cgi.py", line 439, in snap
#     return wfs[-1].intensity.get()
# AttributeError: 'numpy.ndarray' object has no attribute 'get'
# 2023-03-27 12:06:22,788	ERROR worker.py:92 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::CGI.snap() (pid=146119, ip=10.141.18.33, repr=<cgi_phasec_poppy.cgi.CGI object at 0x7f94981b1f10>)
#   File "/home/u21/kianmilani/src/cgi-phasec-poppy/cgi_phasec_poppy/cgi.py", line 439, in snap
#     return wfs[-1].intensity.get()
# AttributeError: 'numpy.ndarray' object has no attribute 'get'

# %% [markdown]
# # Compute different polarization PSFs in parallel.

# %%
reload(cgi)
rayCGI = ray.remote(cgi.CGI)
kwargs = {'cgi_mode':'hlc',
          'use_pupil_defocus':True,
          'use_opds':True}
polaxis = [-2, -1, 1, 2]
actors = []
for i in range(len(polaxis)):
    actors.append(rayCGI.remote(polaxis=polaxis[i], **kwargs))

# %%
pending_ims = []
for i in range(len(actors)):
    actors[i].set_dm1.remote(dm1_flat) # set the DM state for each actor in this loop
    actors[i].set_dm2.remote(dm2_flat)
    future_ims = actors[i].snap.remote()
    pending_ims.append(future_ims)
ims = ray.get(pending_ims)
clear_output()

for i in range(len(actors)):
    misc.imshow1(ims[i], 
                 'POLAXIS = {:d}'.format(polaxis[i]), 
                 pxscl=mode.psf_pixelscale_lamD, xlabel='$\lambda/D$',
                 lognorm=True)

# %%
misc.imshow2(ims[0]-ims[1], ims[1]-ims[2])
